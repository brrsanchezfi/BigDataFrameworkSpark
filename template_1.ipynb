# %%
from FrameworkDatabricks.config.config_loader import ConfigLoader
import os

os.environ["DATABRICKS_WORKSPACE_ID"] = "4142847529395360"
os.environ["DATABRICKS_FRAMEWORK_PATH_ENV"] = "/Workspace/Shared/config/bundle.yml"

env = ConfigLoader()



git config --global user.name "brrsanchezfi"
git config --global user.email "brrsanchezfi@unal.edu.co"

# %%
env.get_config()

# %%
# %sql
SHOW CATALOG
